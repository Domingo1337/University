# %%
# %load_ext sql
# %sql postgresql://domin:domin@localhost/domin
# Out:
# 'Connected: domin@domin'

# %%
! psql -c "\i hsm.dump" > /dev/null
! psql -c "\d"

# %%
! for value in badges comments posthistory postlinks posts tags users votes ; do psql -c "\d $value"; done

# %% [markdown]
# ## Zadanie 1 (2 pkt.)
# Uznajemy, że dany post `A` jest wyczerpującą odpowiedzią na inny post `B`, jeśli `B.AcceptedAnswerID=A.id`. Utwórz ranking użytkowników, którzy wyczerpująco odpowiedzieli na najwięcej pytań. W tym celu zdefiniuj perspektywę `ranking` z polami: `displayname, liczba_odpowiedzi` taką, że użytkownik z danym `displayname` udzielił `liczba_odpowiedzi` wyczerpujących odpowiedzi. Perspektywa powinna być posortowana według liczba_odpowiedzi malejąco,
# a w drugiej kolejności wg `displayname` alfabetycznie

# %%
# %%sql
# -- CREATE VIEW ranking(displayname, liczba_odpowiedzi)AS
# SELECT u.displayname, COUNT(distinct a.id) as liczba_odpowiedzi
#     FROM users u
#     JOIN posts a on u.id = a.owneruserid
#     JOIN posts b on b.acceptedanswerid = a.id
# GROUP BY (u.id, u.displayname)
# ORDER BY liczba_odpowiedzi DESC, displayname ASC;
# Out:
#  * postgresql://domin:***@localhost/domin
# 179 rows affected.
# [('Conifold', 361),
#  ('Alexandre Eremenko', 163),
#  ('Mauro ALLEGRANZA', 96),
#  ('Francois Ziegler', 71),
#  ('HDE 226868', 34),
#  ('Nick', 32),
#  ('Gerald Edgar', 21),
#  ('terry-s', 20),
#  ('Geremia', 16),
#  ('KCd', 14),
#  ('Michael Weiss', 14),
#  ('Dave L Renfro', 12),
#  ('fdb', 12),
#  ('M. Farooq', 12),
#  ('Ben Crowell', 11),
#  ('Danu', 10),
#  ('José Carlos Santos', 10),
#  ('Carl Witthoft', 9),
#  ('Jan Peter Schäfermeyer', 9),
#  ('kimchi lover', 9),
#  ('sand1', 9),
#  ('VicAche', 9),
#  ('Michael E2', 8),
#  ('Viktor Blasjo', 8),
#  ('Logan M', 7),
#  ('Mikhail Katz', 7),
#  ('David Hammen', 6),
#  ('Peter Diehr', 6),
#  ('J. W. Perry', 5),
#  ('Mark Yasuda', 5),
#  ('plannapus', 5),
#  ('quid', 5),
#  ('winwaed', 5),
#  ('jkien', 4),
#  ('K7PEH', 4),
#  ('Otto', 4),
#  ('Uri Granta', 4),
#  ('cesaruliana', 3),
#  ('Colin McLarty', 3),
#  ('hawkeye', 3),
#  ('Jon Custer', 3),
# ...

# %% [markdown]
# ## Zadanie 2 (3 pkt.)
# Wyświetl `id, displayname` i `reputation` użytkowników, którzy
# * nie dostali nigdy odznaki `Enlightened`
# * ale mają więcej `upvotes` niż średnia liczba `upvotes` użytkowników z tą odznaką (uwaga: weź pod uwagę, że jeden użytkownik może dostać jedną odznakę wielokrotnie)
# * oraz napisali więcej niż jeden komentarz pod postami stworzonymi w 2020 r.
# Wynik uporządkuj rosnąco względem daty założenia konta użytkownika.

# %%
# %%sql
# WITH enlightened_users AS
#     (SELECT DISTINCT u.id, u.upvotes FROM users u JOIN badges b ON b.userid = u.id WHERE name='Enlightened')
# SELECT u.id, u.displayname, u.reputation
#     FROM users u
#     JOIN comments c on u.id = c.userid
#     JOIN posts p on p.id = c.postid
# WHERE
#     u.id NOT IN (SELECT id FROM enlightened_users)
# AND u.upvotes > (SELECT AVG(upvotes) FROM enlightened_users)
# AND EXTRACT(YEAR FROM p.creationdate) = 2020
# GROUP BY (u.id, u.displayname, u.reputation, u.creationdate)
# HAVING COUNT(c.id) > 1
# ORDER BY u.creationdate;
# Out:
#  * postgresql://domin:***@localhost/domin
# 7 rows affected.
# [(217, 'peterh - Reinstate Monica', 727),
#  (609, 'Carl Witthoft', 1691),
#  (1932, 'paul garrett', 308),
#  (2905, 'vonbrand', 435),
#  (3462, 'Michael Bächtold', 1272),
#  (3869, 'uhoh', 1105),
#  (6107, 'Moishe Kohan', 491)]

# %% [markdown]
# ## Zadanie 3 (3 pkt.)
# Znajdź użytkowników (`id, displayname`), którzy mają pośredni
# kontakt z rekurencją. Mówimy, że użytkownik ma pośredni kontakt z rekurencją,
# jeśli:
# * w body któregoś posta użył słowa `’recurrence’` lub
# * napisał komentarz do posta osoby, która ma pośredni kontakt z rekurencją.

# %%
# %%sql
# WITH RECURSIVE rec AS (
#     SELECT u.id, u.displayname
#         FROM users u
#         JOIN posts p ON p.owneruserid = u.id
#     WHERE
#         p.body LIKE '%recurrence%'
#     UNION
#     SELECT u.id, u.displayname
#         FROM users u
#         JOIN comments c ON u.id = c.userid
#         JOIN posts p ON p.id = c.postid
#         JOIN rec r ON p.owneruserid = r.id
# )
# SELECT * FROM rec;
# Out:
#  * postgresql://domin:***@localhost/domin
# 805 rows affected.
# [(55, 'Conifold'),
#  (100, 'user153012'),
#  (134, 'MJD'),
#  (232, 'Geremia'),
#  (3329, 'sand1'),
#  (48, 'Michael Weiss'),
#  (8, 'VicAche'),
#  (62, 'HDE 226868'),
#  (26, 'Danu'),
#  (58, 'Logan M'),
#  (27, 'Ali Caglayan'),
#  (64, 'Alexandre Eremenko'),
#  (131, 'Mauro ALLEGRANZA'),
#  (327, 'James S. Cook'),
#  (364, 'fdb'),
#  (163, 'Guido Jorg'),
#  (261, 'dotancohen'),
#  (492, 'Jeffrey Kegler'),
#  (520, 'hjhjhj57'),
#  (50, 'Jack M'),
#  (557, 'Willemien'),
#  (167, 'Pasha Zusmanovich'),
#  (536, 'IanF1'),
#  (142, 'David H'),
#  (643, 'KCd'),
#  (1744, 'Teusz'),
#  (65, 'Ooker'),
#  (1830, 'Tom Copeland'),
#  (229, 'Gerald Edgar'),
#  (466, 'Ben Crowell'),
#  (1957, 'Rammus'),
#  (1817, 'Marius Kempe'),
#  (1998, 'Rok'),
#  (2075, 'K7PEH'),
#  (2127, 'Barun'),
#  (1843, 'David Hammen'),
#  (2891, 'Kushal Bhuyan'),
#  (1994, 'Quantum spaghettification'),
#  (1706, 'Adam'),
#  (2229, 'David Holden'),
# ...
